# %%
#Q1
for i in range(5) :
    name = input("Enter your name: ")
    with open("names.txt", "w") as f :
        f.write(name)

with open("names.txt", "r") as f :
    print(f.read())

# %%
#Q2
with open("log.txt", "a") as f :
    f.append("Program run Successfully")
with open("log.txt", "r") as f  :
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 #Q2
#       2 with open("log.txt", "a") as f :
# ----> 3     f.append("Program run Successfully")
#       4 with open("log.txt", "r") as f  :
#       5     print(f.read())
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'append'

# %%
#Q3
l = [5, 10, 15, 25, 40, 30, 57]
[i for i in l if i > 15]
#print(x)
# Out:
# [25, 40, 30, 57]

# %%
#Q4
import json
with open("cities.json", "r") as f :
    file = json.load(f)
    print(file)
# Out:
# {'dhaka': '3cr', 'rajshahi': '1.5cr', 'chattragram': '80lakh', 'sylet': '2cr'}

# %%
#5
try :
    with open("data.txt", "r") as f :
        print("file is founded")
except :
    print("file not found")
# Out:
# file not found
