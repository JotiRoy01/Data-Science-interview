# %%
#Q1
class BankAccount :
    account_number = "0XXXXX"
    owner_name = "joti"
    balance = 50_000

    def deposit(self, balance) :
        self.balance = BankAccount.balance + balance
    
    def withdraw(self, balance) :
        self.balance = BankAccount.balance - balance

    def check_balance(self) :
        return BankAccount.balance

# %%
#Q2
class BOOK :
    title = "Think slowly and fast"
    author = "joti"
    list_review = 0

    def new_review() :
        list_review += 1

    def count_review() :
        re
