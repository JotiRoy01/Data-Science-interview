# %%
f = open("sample.txt","r") #return file object

# %%
data = f.read()

# %%
data
# Out:
# 'This is data science cource\nfor of demo\npython'

# %%
type(data)
# Out:
# str

# %%
f.close()

# %%
line = f.readline()

# %%
line
# Out:
# 'This is data science cource\n'

# %%
f = open("sample.txt","w") #return file object

# %%
f.write("text to overwrite\n the complete data")
# Out:
# 36

# %%
f = open("sample.txt","a")
f.write("add new txt")
# Out:
# 11

# %%
f.close()

# %%
#create a new file by x
f = open("sample1.txt", "x")
f.write("add new file")
f.close()

# %% [markdown]
# ### Data format mode

# %%
# b -> binary mode

# %% [markdown]
# plus mode

# %%
f = open("sample.txt", "r+") 
f.write("123")
print(f.read())
f.close()
# Out:
# t to overwrite
#  the complete datae fileadd new txt

# %%
f = open("sample.txt", "w+") 
f.write("1234")
print(f.read())
f.close()

# %%
# With keyword

with open("sample.txt", 'r') as f :
    print(f.read())
# Out:
# 1234

# %%
# os module
import os

os.remove("sample1.txt")

# %% [markdown]
# ### Words Search

# %%
data = True
with open("sample.txt", "r") as f :

    while data :
        data = f.readline()
        print(data)
